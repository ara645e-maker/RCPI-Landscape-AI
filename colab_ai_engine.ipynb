# %% [markdown]
# # Colab AI Engine for Free T4 Deployment
#
# This notebook prepares a free Google Colab T4 GPU environment for running:
# - Ollama with `qwen2-vl/llava`
# - Stable Diffusion image generation
# - A small API server exposed via Ngrok/localtunnel
#
# It also includes instructions to connect this Colab GPU engine to your FastAPI backend.
